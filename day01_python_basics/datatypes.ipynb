# %% [markdown]
# ### Jupyter Shortcuts
# + esc + a - Add a cell above the current cell
# + esc + b - Add a cell below the current cell
# + esc + m - Convert to markdown cell
# + esc + y - Convert to code cell
# + esc + x - Delete the current cell

# %%
# This is a comment
print('Hello')
# Out:
# Hello

# %% [markdown]
# ### Basic Datatypes

# %%
# Integer
x = 10

# %%
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 10

# %%
x
# Out:
# 10

# %%
# Float
y = 10.24

# %%
type(y)
# Out:
# float

# %%
# Boolean
z = True

# %%
type(z)
# Out:
# bool

# %%
z
# Out:
# True

# %% [markdown]
# ### Arithmetic Operations

# %%
x = 10
y = 32

# %%
# Addition
x + y
# Out:
# 42

# %%
# SUbtraction
x - y
# Out:
# -22

# %%
# Multiplication
x * y
# Out:
# 320

# %%
# Division
x / y
# Out:
# 0.3125

# %%
# Modulo Division
x % y
# Out:
# 10

# %%
# Floor Division
x // y
# Out:
# 0

# %%
-x // y
# Out:
# -1

# %%
# Power Operation
x ** 3
# Out:
# 1000

# %% [markdown]
# ### Boolean Operations

# %%
c1 = True
c2 = False

# %%
c1 and c2
# Out:
# False

# %%
c1 or c2
# Out:
# True

# %% [markdown]
# ### Collections

# %% [markdown]
# #### a. Sequences

# %%
# 1. List
lst = [56,78,89,23,90,55,70,100, 59]
lst
# Out:
# [56, 78, 89, 23, 90, 55, 70, 100, 59]

# %%
type(lst)
# Out:
# list

# %%
# 2. Tuple
t1 = (56,78,89,23,90,55,70,100, 59)
t1
# Out:
# (56, 78, 89, 23, 90, 55, 70, 100, 59)

# %%
type(t1)
# Out:
# tuple

# %%
# 3. String
s1 = "Hello World"
s1
# Out:
# 'Hello World'

# %%
type(s1)
# Out:
# str

# %%
lst[4]
# Out:
# 90

# %%
t1[7]
# Out:
# 100

# %%
s1[1]
# Out:
# 'e'

# %%
shop_lst = ['Apple','Rice','Soap','Chicken','Oil','Bread']
shop_lst
# Out:
# ['Apple', 'Rice', 'Soap', 'Chicken', 'Oil', 'Bread']

# %%
shop_lst[2]
# Out:
# 'Soap'

# %%
mixed_lst = [10, 2.456, True, [1,2,3], (11,22,33), 'Hello']
mixed_lst
# Out:
# [10, 2.456, True, [1, 2, 3], (11, 22, 33), 'Hello']

# %%
mixed_lst[4]
# Out:
# (11, 22, 33)

# %%
mixed_lst[4][1]
# Out:
# 22

# %% [markdown]
# ##### Slicing a sequence

# %%
lst
# Out:
# [56, 78, 89, 23, 90, 55, 70, 100, 59]

# %%
lst[2:6]
# Out:
# [89, 23, 90, 55]

# %%
s2 = 'I love python'

# %%
s2[2:6]
# Out:
# 'love'

# %%
shop_lst
# Out:
# ['Apple', 'Rice', 'Soap', 'Chicken', 'Oil', 'Bread']

# %%
shop_lst[1:4]
# Out:
# ['Rice', 'Soap', 'Chicken']

# %%
shop_lst[:4]
# Out:
# ['Apple', 'Rice', 'Soap', 'Chicken']

# %%
shop_lst[3:]
# Out:
# ['Chicken', 'Oil', 'Bread']

# %%
shop_lst[:]
# Out:
# ['Apple', 'Rice', 'Soap', 'Chicken', 'Oil', 'Bread']

# %%
lst
# Out:
# [56, 78, 89, 23, 90, 55, 70, 100, 59]

# %%
lst[1:7:2]
# Out:
# [78, 23, 55]

# %%
lst[7:2:-1]
# Out:
# [100, 70, 55, 90, 23]

# %%
# Reverses the list
lst[::-1]
# Out:
# [59, 100, 70, 55, 90, 23, 89, 78, 56]

# %%
name = 'darshan'
name[::-1]
# Out:
# 'nahsrad'

# %% [markdown]
# ##### Negative Indexing

# %%
lst[-1]
# Out:
# 59

# %%
lst[-3]
# Out:
# 70

# %%
shop_lst[-1]
# Out:
# 'Bread'

# %% [markdown]
# #### Iterate Over a Sequence

# %%
shop_lst
# Out:
# ['Apple', 'Rice', 'Soap', 'Chicken', 'Oil', 'Bread']

# %%
for x in shop_lst:
    print(x)
    print('Hi')
print('_________________')
# Out:
# Apple
# Hi
# Rice
# Hi
# Soap
# Hi
# Chicken
# Hi
# Oil
# Hi
# Bread
# Hi
# _________________

# %%
x = 45
print(x,'$')
# Out:
# 45 $

# %%
price = [50,78,150,230,65]
for x in price:
    print('$',x)
print('Completed')
# Out:
# $ 50
# $ 78
# $ 150
# $ 230
# $ 65
# Completed

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for x in range(1,6):
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(1,11,2):
    print(x)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
st1 = 'hello'

# %%
for x in st1:
    print(x)
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# #### Common Functions

# %%
lst
# Out:
# [56, 78, 89, 23, 90, 55, 70, 100, 59]

# %%
max(lst)
# Out:
# 100

# %%
min(lst)
# Out:
# 23

# %%
len(lst)
# Out:
# 9

# %%
sum(lst)
# Out:
# 620

# %%
sum(lst) / len(lst)
# Out:
# 68.88888888888889

# %%
s2
# Out:
# 'I love python'

# %%
len(s2)
# Out:
# 13

# %% [markdown]
# #### membership operation

# %%
shop_lst
# Out:
# ['Apple', 'Rice', 'Soap', 'Chicken', 'Oil', 'Bread']

# %%
'Pen' in shop_lst
# Out:
# False

# %%
'Bread' in shop_lst
# Out:
# True

# %%
st1
# Out:
# 'hello'

# %%
'e' in st1
# Out:
# True

# %%
'z' in st1
# Out:
# False

# %% [markdown]
# #### Arithmetic Operators - '+' & '*'

# %% [markdown]
# #####  + -> Concatenation

# %%
l1 = [1,2,3]
l2 = [4,5,6]

l1 + l2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
s1 = 'Hello'
s2 = 'World'

s1 + s2
# Out:
# 'HelloWorld'

# %% [markdown]
# #####  * -> Repetition

# %%
s1 * 3
# Out:
# 'HelloHelloHello'

# %%
l1
# Out:
# [1, 2, 3]

# %%
l1 * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
'_'* 50
# Out:
# '__________________________________________________'

# %% [markdown]
# ## Home Work

# %%
for i in range(1,8):
    print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
n = 5
for i in range(1, n+1):
    spaces = n - i
    stars = 2*i - 1
    print(spaces*' ', stars*'*')
# Out:
#                *
#               ***
#              *****
#             *******
#            *********
#           ***********
#          *************
#         ***************
#        *****************
#       *******************
#      *********************
#     ***********************
#    *************************
#   ***************************
#  *****************************

# %% [markdown]
# ### List

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lst
# Out:
# [56, 78, 89, 23, 90, 55, 70, 100, 59]

# %% [markdown]
# #### Adding elements to a list

# %%
lst.append(99)
lst
# Out:
# [56, 78, 89, 23, 90, 55, 70, 100, 59, 99]

# %%
lst.extend( [1,2,3] )
lst
# Out:
# [56, 78, 89, 23, 90, 55, 70, 100, 59, 99, 1, 2, 3]

# %%
lst.insert(3,11)
lst
# Out:
# [56, 78, 89, 11, 23, 90, 55, 70, 100, 59, 99, 1, 2, 3]

# %%
shop_lst
# Out:
# ['Apple', 'Rice', 'Soap', 'Chicken', 'Oil', 'Bread']

# %%
shop_lst.append('Butter')
shop_lst
# Out:
# ['Apple', 'Rice', 'Soap', 'Chicken', 'Oil', 'Bread', 'Butter']

# %%
shop_lst.extend( ['Jam','Shampoo'])
shop_lst
# Out:
# ['Apple',
#  'Rice',
#  'Soap',
#  'Chicken',
#  'Oil',
#  'Bread',
#  'Butter',
#  'Jam',
#  'Shampoo']

# %%
shop_lst.insert(5,'Pencil')
shop_lst
# Out:
# ['Apple',
#  'Rice',
#  'Soap',
#  'Chicken',
#  'Oil',
#  'Pencil',
#  'Bread',
#  'Butter',
#  'Jam',
#  'Shampoo']

# %% [markdown]
# #### Remove elements to a list

# %%
lst
# Out:
# [56, 78, 89, 11, 23, 90, 55, 70, 100, 59, 99, 1, 2, 3]

# %%
lst.pop()
lst
# Out:
# [56, 78, 89, 11, 23, 90, 55, 70, 100, 59, 99, 1, 2]

# %%
lst.pop()
lst
# Out:
# [56, 78, 89, 11, 23, 90, 55, 70, 100, 59, 99, 1]

# %%
lst.pop(3)
lst
# Out:
# [56, 78, 89, 23, 90, 55, 70, 100, 59, 99, 1]

# %%
shop_lst
# Out:
# ['Apple',
#  'Rice',
#  'Soap',
#  'Chicken',
#  'Oil',
#  'Pencil',
#  'Bread',
#  'Butter',
#  'Jam',
#  'Shampoo']

# %%
shop_lst.remove('Pencil')
shop_lst
# Out:
# ['Apple',
#  'Rice',
#  'Soap',
#  'Chicken',
#  'Oil',
#  'Bread',
#  'Butter',
#  'Jam',
#  'Shampoo']

# %%
lst.remove(90)
lst
# Out:
# [56, 78, 89, 23, 55, 70, 100, 59, 99, 1]

# %%
l1
# Out:
# [1, 2, 3]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %% [markdown]
# #### Arranging elements in a list

# %%
lst
# Out:
# [56, 78, 89, 23, 55, 70, 100, 59, 99, 1]

# %%
# Ascending Order
lst.sort(reverse=False)
lst
# Out:
# [1, 23, 55, 56, 59, 70, 78, 89, 99, 100]

# %%
# Descending Order
lst.sort(reverse=True)
lst
# Out:
# [100, 99, 89, 78, 70, 59, 56, 55, 23, 1]

# %%
lst1 = [34,53,21]
lst1.reverse()
lst1
# Out:
# [21, 53, 34]

# %% [markdown]
# #### count() & index()

# %%
name_lst = ['Tim','Jim','Kim','Pim','Jim']
name_lst.count('Jim')
# Out:
# 2

# %%
name_lst.count('Tim')
# Out:
# 1

# %%
name_lst.index('Kim')
# Out:
# 2

# %%
name_lst.index('Jim')
# Out:
# 1

# %% [markdown]
# ### Assignment vs Copy

# %% [markdown]
# ##### assignment

# %%
l1 = [1,2,3]
l2 = l1

# %%
l1
# Out:
# [1, 2, 3]

# %%
l2
# Out:
# [1, 2, 3]

# %%
l2.append(100)

# %%
l2
# Out:
# [1, 2, 3, 100]

# %%
l1
# Out:
# [1, 2, 3, 100]

# %% [markdown]
# ##### copy()

# %%
l1 = [1,2,3]
l2 = l1.copy()

# %%
l1
# Out:
# [1, 2, 3]

# %%
l2
# Out:
# [1, 2, 3]

# %%
l2.append(100)

# %%
l2
# Out:
# [1, 2, 3, 100]

# %%
l1
# Out:
# [1, 2, 3]

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %% [markdown]
# #### string

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
s1 = 'i love python'

# %%
s1.capitalize()
# Out:
# 'I love python'

# %%
s1.title()
# Out:
# 'I Love Python'

# %%
si_up = s1.upper()

# %%
si_up
# Out:
# 'I LOVE PYTHON'

# %%
s2 = 'Python'

# %%
s2.lower()
# Out:
# 'python'

# %%
s1
# Out:
# 'i love python'

# %%
s2
# Out:
# 'Python'

# %%
s2.swapcase()
# Out:
# 'pYTHON'

# %%
s3 = 'Anarkali'

# %%
s3.replace('Anar','Champa')
# Out:
# 'Champakali'

# %%
price = '$500'
price.replace('$','')
# Out:
# '500'

# %%
s4 = 'python'

# %%
s4.startswith('py'), s4.startswith('on')
# Out:
# (True, False)

# %%
s4.endswith('py'), s4.endswith('on')
# Out:
# (False, True)

# %%
s5 = '   python   '

# %%
s5.lstrip(), s5.rstrip(), s5.strip()
# Out:
# ('python   ', '   python', 'python')

# %%
s6 = 'This is a big text used to show how to use split function in python'

# %%
# Tokenize
word_list = s6.split()
word_list
# Out:
# ['This',
#  'is',
#  'a',
#  'big',
#  'text',
#  'used',
#  'to',
#  'show',
#  'how',
#  'to',
#  'use',
#  'split',
#  'function',
#  'in',
#  'python']

# %%
fruits = 'Apple,Orange,Grapes,Kiwi,Mango'

# %%
fruit_list = fruits.split(',')
fruit_list
# Out:
# ['Apple', 'Orange', 'Grapes', 'Kiwi', 'Mango']

# %%
fruits = 'Apple|Orange|Grapes|Kiwi|Mango'

# %%
fruits.split('|')
# Out:
# ['Apple', 'Orange', 'Grapes', 'Kiwi', 'Mango']

# %%
s7 = 'This is a small text'

# %%
words = s7.split()
words
# Out:
# ['This', 'is', 'a', 'small', 'text']

# %%
' '.join(words)
# Out:
# 'This is a small text'

# %%
'|'.join(words)
# Out:
# 'This|is|a|small|text'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 membershhip
#
# NameError: name 'membershhip' is not defined
